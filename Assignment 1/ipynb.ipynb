# %%
import platform

print(f"I am running on Google's servers: {platform.node()}")
# Out:
# I am running on Google's servers: DeAnnas-MacBook-Air.local

# %%
name = input("Enter your name: ")

print(f"Happy coding, {name}!")
# Out:
# Happy coding, DeAnna!

# %% [markdown]
# # Local Test Success
